# %%
import csv
import pandas as pd

fh = open("Consensus_Data_California_2022.csv")
fh2 = open("Consensus_Data_Texas_2022.csv")
texasData = list(csv.reader(fh2))
caliData = list(csv.reader(fh))
print(texasData)

columnHeaders = texasData[0]
columnHeaders[0] = columnHeaders[0].split("\ufeff")
columnHeaders[0] = columnHeaders[0][1]
print(columnHeaders)
# Out:
# [['\ufeffLabel (Grouping)', 'Owner-occupied housing units with a mortgage (Estimate)', 'Owner-occupied housing units with a mortgage (Margin of Error)', 'Percent owner-occupied housing units with a mortgage (Estimate)', 'Percent owner-occupied housing units with a mortgage (Margin of Error)'], ['Owner-occupied housing units with a mortgage', '3,884,497', '±29,551', '3,884,497', '±29,551'], ['\xa0\xa0\xa0\xa0VALUE', '', '', '', ''], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Less than $50,000', '110,664', '±6,769', '2.80%', '±0.2'], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$50,000 to $99,999', '154,606', '±7,997', '4.00%', '±0.2'], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$100,000 to $299,999', '1,554,218', '±24,643', '40.00%', '±0.5'], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$300,000 to $499,999', '1,212,621', '±20,058', '31.20%', '±0.5'], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$500,000 to $749,999', '513,525', '±12,315', '13.20%', '±0.3'], ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$750,000 to $999,999', '192,865', '±8,436',
# ...
